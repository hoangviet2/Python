# %%
import os
os.listdir()
# Out:
# ['nameAsking.py',
#  'whileLoop.py',
#  'English Dictionary',
#  '.DS_Store',
#  'userinput.py',
#  'forloop.py',
#  'loopdict.py',
#  'Untitled.ipynb',
#  'textpro.py',
#  'Testing notebook.ipynb',
#  'touple.py',
#  'readingfile.py',
#  'basic_old.py',
#  'fruit.txt',
#  'README.md',
#  '.gitignore',
#  'basic.py',
#  'temps_today.csv',
#  'vegetables.txt',
#  '.ipynb_checkpoints',
#  'modules.py',
#  '.git',
#  'source.py',
#  'function.py',
#  'lab.py']

# %%
os.listdir()
# Out:
# ['nameAsking.py',
#  'whileLoop.py',
#  'English Dictionary',
#  '.DS_Store',
#  'userinput.py',
#  'forloop.py',
#  'loopdict.py',
#  'Untitled.ipynb',
#  'textpro.py',
#  'Testing notebook.ipynb',
#  'touple.py',
#  'supermarkets.json',
#  'readingfile.py',
#  'basic_old.py',
#  'supermarkets.csv',
#  'fruit.txt',
#  'README.md',
#  'supermarkets-semi-colons.txt',
#  '.gitignore',
#  'basic.py',
#  'supermarkets.xlsx',
#  'temps_today.csv',
#  'vegetables.txt',
#  '.ipynb_checkpoints',
#  'modules.py',
#  '.git',
#  'source.py',
#  'supermarkets-commas.txt',
#  'function.py',
#  'lab.py']

# %%
import pandas

# %%
df1 = pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
import pandas
df3 = pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
import pandas
df4 = pandas.read_csv("supermarkets-commas.txt",header = None)
df4.columns = ["ID","Address","City","State","Country","Name","Employees"]

# %%
import pandas
df2 = pandas.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
import geopy
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'Geocodio',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'HereV7',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'What3WordsV3',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_info__',
#  'adapters',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'get_version',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy import Location
dir(Location)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_address',
#  '_point',
#  '_raw',
#  '_tuple',
#  'address',
#  'altitude',
#  'latitude',
#  'longitude',
#  'point',
#  'raw']

# %%
from geopy import ArcGIS
dir(ArcGIS)
# Out:
# ['_TOKEN_EXPIRED',
#  '__aenter__',
#  '__aexit__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adapter_error_handler',
#  '_authenticated_call_geocoder',
#  '_call_geocoder',
#  '_coerce_point_to_string',
#  '_format_bounding_box',
#  '_geocoder_exception_handler',
#  '_parse_geocode',
#  '_parse_reverse',
#  '_refresh_authentication_token',
#  'auth_path',
#  'geocode',
#  'geocode_path',
#  'reverse',
#  'reverse_path']

# %%
nom = ArcGIS()

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94144")
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1256         """Send a complete request to the server."""
# -> 1257         self._send_request(method, url, body, headers, encode_chunked)
#    1258
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1302             body = _encode(body, 'body')
# ...

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()
nom.geocode("3995 23rd St, San Francisco, CA 94144")
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.75292099814533, -122.43170295955227, 0.0))

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()
nom.geocode("One Apple Park Way, Cupertino, CA 95014")
# Out:
# Location(1 Apple Park Way, Cupertino, California, 95014, (37.3353370126967, -122.00957103725969, 0.0))

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()
n = nom.geocode("One Apple Park Way, Cupertino, CA 95014")

# %%
n.latitude
n.longitude
# Out:
# -122.00957103725969

# %%
import pandas
df1 = pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1["Address"] = df1["Address"]+", "+df["City"]+", "+df["State"]+", "+df["Country"]
df1["Address"]
# Out:
#   File "/var/folders/6m/kf6pyh9s3tl4cqk5gz2ryjr80000gn/T/ipykernel_23167/1473870882.py", line 1
#     df1["Address"] = df1["Address"]+", "df["City"]+", "df["State"]+", "df["Country"]
#                                         ^
# SyntaxError: invalid syntax

# %%
df1["Address"] = df1["Address"]+", "+df["City"]+", "+df["State"]+", "+df["Country"]
df1["Address"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6m/kf6pyh9s3tl4cqk5gz2ryjr80000gn/T/ipykernel_23167/187545908.py in <module>
# ----> 1 df1["Address"] = df1["Address"]+", "+df["City"]+", "+df["State"]+", "+df["Country"]
#       2 df1["Address"]
#
# NameError: name 'df' is not defined

# %%
import pandas
df1 = pandas.read_csv("supermarkets.csv")
df1["Address"] = df1["Address"]+", "+df["City"]+", "+df["State"]+", "+df["Country"]
df1["Address"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6m/kf6pyh9s3tl4cqk5gz2ryjr80000gn/T/ipykernel_23167/372192812.py in <module>
#       1 import pandas
#       2 df1 = pandas.read_csv("supermarkets.csv")
# ----> 3 df1["Address"] = df1["Address"]+", "+df["City"]+", "+df["State"]+", "+df["Country"]
#       4 df1["Address"]
#
# NameError: name 'df' is not defined

# %%
import pandas
df1 = pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1["Address"] = df1["Address"]+", "+df1["City"]+", "+df1["State"]+", "+df1["Country"]
df1["Address"]
# Out:
# 0           3666 21st St, San Francisco, CA 94114, USA
# 1         735 Dolores St, San Francisco, CA 94119, USA
# 2    332 Hill St, San Francisco, California 94114, USA
# 3           3995 23rd St, San Francisco, CA 94114, USA
# 4      1056 Sanchez St, San Francisco, California, USA
# 5        551 Alvarado St, San Francisco, CA 94114, USA
# Name: Address, dtype: object

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()
df1["Coordinates"] = df1["Address"].apply(nom.geocode())
df1.Coordinates
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/6m/kf6pyh9s3tl4cqk5gz2ryjr80000gn/T/ipykernel_23167/1801414282.py in <module>
#       1 from geopy.geocoders import ArcGIS
#       2 nom = ArcGIS()
# ----> 3 df1["Coordinates"] = df1["Address"].apply(nom.geocode())
#       4 df1.Coordinates
#
# TypeError: geocode() missing 1 required positional argument: 'query'

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()
df1["Coordinates"] = df1["Address"].apply(nom.geocode)
df1.Coordinates
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/6m/kf6pyh9s3tl4cqk5gz2ryjr80000gn/T/ipykernel_23167/1801414282.py in <module>
#       1 from geopy.geocoders import ArcGIS
#       2 nom = ArcGIS()
# ----> 3 df1["Coordinates"] = df1["Address"].apply(nom.geocode())
#       4 df1.Coordinates
#
# TypeError: geocode() missing 1 required positional argument: 'query'

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()
df1["Coordinates"] = df1["Address"].apply(nom.geocode)
df1.Coordinates
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1256         """Send a complete request to the server."""
# -> 1257         self._send_request(method, url, body, headers, encode_chunked)
#    1258
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1302             body = _encode(body, 'body')
# ...

# %% [markdown]
# df1["Coordinates"] = df1["Address"].apply(nom.geocode)
# df1.Coordinates

# %%
df1["Coordinates"] = df1["Address"].apply(nom.geocode)
df1.Coordinates
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1256         """Send a complete request to the server."""
# -> 1257         self._send_request(method, url, body, headers, encode_chunked)
#    1258
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1302             body = _encode(body, 'body')
# ...

# %%
df1["Coordinates"] = df1["Address"].apply(nom.geocode)
df1.Coordinates
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1256         """Send a complete request to the server."""
# -> 1257         self._send_request(method, url, body, headers, encode_chunked)
#    1258
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1302             body = _encode(body, 'body')
# ...

# %%
df1["Coordinates"] = df1["Address"].apply(nom.geocode)
df1.Coordinates
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1256         """Send a complete request to the server."""
# -> 1257         self._send_request(method, url, body, headers, encode_chunked)
#    1258
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1302             body = _encode(body, 'body')
# ...
