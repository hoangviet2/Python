# %%
import pandas
data = pandas.read_excel("Diem-XetTuyen- TPHCM-2021.xlsx")
chuyentin = data.groupby(['MonChuyen']).get_group("CTIN")
chuyentin
# Out:
#          SBD  Ngày Sinh MonChuyen  Toan  Van  NgoaiNgu  DiemTBMonChuyen  \
# 80      9272 2006-10-21      CTIN   9.0  8.3       8.5              9.0
# 249     9166 2006-09-28      CTIN   8.3  7.6       9.5              8.3
# 259    91859 2006-01-03      CTIN   8.9  8.1       9.2              8.9
# 479     9285 2006-03-18      CTIN   9.0  8.2       9.1              9.0
# 780     9232 2006-06-04      CTIN   9.0  8.0       9.4              9.0
# ...      ...        ...       ...   ...  ...       ...              ...
# 75982   9223 2006-01-01      CTIN   9.3  9.1       9.3              9.3
# 76086   9265 2006-04-23      CTIN   9.5  9.0       8.5              9.5
# 76583   9252 2006-06-05      CTIN   8.9  8.0       9.0              8.9
# 78274  95344 2006-11-09      CTIN   9.1  8.4       9.1              9.1
# 82813   9199 2006-04-12      CTIN   8.9  7.8       8.3              8.9
#
#        DiemUTKK10  DiemKKChuyen  TongDiemThuong  \
# 80            NaN           NaN            25.8
# ...
