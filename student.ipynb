# %%
import requests
import datetime
from bs4 import BeautifulSoup
import pandas
base_url = "https://thanhnien.vn/giao-duc/tuyen-sinh/2021/tra-cuu-diem-thi-lop-10.html#9000"
request = requests.get(base_url)
contents = request.content
readableContent = BeautifulSoup(contents,"html.parser")

# %%
readableContent
# Out:
# <!DOCTYPE html>
#
# <html itemscope="" itemtype="http://schema.org/WebSite" prefix="og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <script>
# var redirectMobile = false; var isIAB = false;
# try { if (window.outerWidth < 1010) { if (/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|mobile.+firefox|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows ce|xda|xiino/i.test(navigator.userAgent || navigator.vendor || window.opera)) {
# redirectMobile = true;
# if (/(FBAV|FB_IAB)/i.test(navigator.userAgent || navigator.vendor || window.opera)) {
# isIAB = true;
# } else {
# window.location = '//m.thanhnien.vn' + window.location.pathname + window.location.search;
# }
# }}} catch (ex) { }</script><title>
# 	Tra cứu điểm thi Lớp 10 2021 theo tên, bằng số báo danh | Thanh Niên
# </title>
# ...

# %%
divtag = readableContent.find("div",{"class":"result-table"})
tbodytag = divtag.find_all("tbody",{"id":"resultcontainer"})
divtag
# Out:
# <div class="result-table">
# <table class="table ptnk-tab-container-2">
# <thead>
# <tr class="result-table-header">
# <th colspan="1" rowspan="2">STT</th>
# <th colspan="1" rowspan="2">Khu vực</th>
# <th colspan="1" rowspan="2">Họ tên</th>
# <th class="" colspan="1" rowspan="2">Số báo danh</th>
# <th colspan="1" rowspan="2">Ngày sinh</th>
# <th colspan="1" rowspan="2">Giới tính</th><th class="mobile-tab-content mobile-tab-4 mobile-tab-5" colspan="12" rowspan="1">Môn thi</th>
# <th colspan="1" rowspan="2">Tổng điểm</th>
# </tr>
# <tr>
# <th class="table-hdr-scores" colspan="1" rowspan="1">D1</th>
# <th class="table-hdr-scores" colspan="1" rowspan="1">D2</th>
# <th class="table-hdr-scores" colspan="1" rowspan="1">D3</th>
# <th class="table-hdr-scores" colspan="1" rowspan="1">D4</th>
# <th class="table-hdr-scores" colspan="1" rowspan="1">D5</th>
# <th class="table-hdr-scores" colspan="1" rowspan="1">D6</th>
# <th class="table-hdr-scores" colspan="1" rowspan="1">D7</th>
# ...
